# %%
from vespa.application import Vespa

# Path to your security files
cert_path = "/Users/shivamjogdand/Desktop/Learning/DeepAgents/Report_Generation_Git/Report_Generation/certs/public.pem"
key_path = "/Users/shivamjogdand/Desktop/Learning/DeepAgents/Report_Generation_Git/Report_Generation/certs/private.pem"
endpoint_url = "https://b59fb6c4.ff57cf01.z.vespa-app.cloud"

app = Vespa(
    url=endpoint_url,
    cert=cert_path,
    key=key_path
)

# %%
query = {
    "yql": "select page_number "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\""
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND page_number = 172 ",
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/ed36f463b6bdf4da9d7bf591',
#   'relevance': 0.0017429193899782135,
#   'source': 'pefund',
#   'fields': {'page_number': 172}}]

# %%
query = {
    "yql": "select content_summary_chunk, url, tenant_id, file_id "
           "from sources pefund.summary "
           "where tenant_id contains \"90da21d0-8e83-4e84-961b-e6fec8b9dafe\" "
           "AND doc_type IN ('apollo')",
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/8bb5524d2d6e58f6158a55a0',
#   'relevance': 0.0,
#   'source': 'pefund',
#   'fields': {'matchfeatures': {'bm25(content_summary_chunk)': 0.0,
#     'cos_sim': -0.9999876894265599,
#     'max_sim': 0.0},
#    'content_summary_chunk': '# PhonePe\n*Comprehensive organizational profile and funding information*\n\n## Company Overview\n**Headquarters Location**: Based in None, None, this organization operates in the heart of the business ecosystem.\n\n**Industry Sector**: The company specializes in the information technology & services industry, contributing to innovation and growth in this sector.\n\n**Company Website**: [Visit their official website](http://www.phonepe.com) to learn more about their products and services.\n\n**Establishment Date**: Founded in 2015, the company has been serving the market for 9 years.',
#    'url': 'https://s3-qa-8byte.s3.ap-south-1.amazonaws.com/phonepe%2Fin%2Fphonepe_apollo.pdf',
# ...

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund " 
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\"",
    "hits": 0,
    "presentation.timing": True 
}

result = app.query(body=query)

total_count = result.number_documents_retrieved 
print(f"Total records found: {total_count}")
# Out:
# Total records found: 288

# %% [markdown]
# # offset 0

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND title contains \"CONSOLIDATED STATEMENT\" " ,
           "offset": 0,
              "hits": 10
           
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/abda14663cfc2056159a7d28',
#   'relevance': 0.38360530298949064,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
#    'content': 'Consolidated financial statements 164 | Non-financial information 261\n\nA comprehensive view of our financial and non-financial performance, including complete financial statements and sustainability metrics and assurance disclosures.',
#    'url': 'https://s3-qa-8byte.s3.ap-south-1.amazonaws.com/sabic%2Fin%2Fsabic_in_sabic_cc_compressed.pdf',
#    'page_number': 163,
#    'tenant_id': '0f7a4b5f-a137-4a71-b518-1a04ba239b61'}},
#  {'id': 'index:pefund/0/c89cdd4f163e8d0f237beda3',
#   'relevance': 0.38360530298949064,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENT OF FINANCIAL POSITION',
# ...

# %% [markdown]
# # offset 1

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND title contains \"CONSOLIDATED STATEMENT\" " ,
           "offset": 1,
              "hits": 10
           
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/c89cdd4f163e8d0f237beda3',
#   'relevance': 0.38360530298949064,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENT OF FINANCIAL POSITION',
# ...

# %% [markdown]
# # offset 10

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND title contains \"CONSOLIDATED STATEMENT\" " ,
           "offset": 10,
              "hits": 10
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/13e8378e011ee19b8fd4e043',
#   'relevance': 0.38360530298949064,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
# ...

# %% [markdown]
# # UserQuery()

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND userQuery() " ,
           "query": "CONSOLIDATED STATEMENT",
           "offset": 0,
              "hits": 10
           
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/abda14663cfc2056159a7d28',
#   'relevance': 0.2863612897055808,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
#    'content': 'Consolidated financial statements 164 | Non-financial information 261\n\nA comprehensive view of our financial and non-financial performance, including complete financial statements and sustainability metrics and assurance disclosures.',
#    'url': 'https://s3-qa-8byte.s3.ap-south-1.amazonaws.com/sabic%2Fin%2Fsabic_in_sabic_cc_compressed.pdf',
#    'page_number': 163,
#    'tenant_id': '0f7a4b5f-a137-4a71-b518-1a04ba239b61'}},
#  {'id': 'index:pefund/0/b56c6a9f53a1ff968b2d446e',
#   'relevance': 0.24698722051238778,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
# ...

# %% [markdown]
# # near Operator

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\" "
           "AND title contains near(\"CONSOLIDATED\", \"STATEMENT\") " ,
           "offset": 0,
              "hits": 10
           
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/abda14663cfc2056159a7d28',
#   'relevance': 0.33749934257751296,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
#    'content': 'Consolidated financial statements 164 | Non-financial information 261\n\nA comprehensive view of our financial and non-financial performance, including complete financial statements and sustainability metrics and assurance disclosures.',
#    'url': 'https://s3-qa-8byte.s3.ap-south-1.amazonaws.com/sabic%2Fin%2Fsabic_in_sabic_cc_compressed.pdf',
#    'page_number': 163,
#    'tenant_id': '0f7a4b5f-a137-4a71-b518-1a04ba239b61'}},
#  {'id': 'index:pefund/0/c89cdd4f163e8d0f237beda3',
#   'relevance': 0.33749934257751296,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENT OF FINANCIAL POSITION',
# ...

# %% [markdown]
# # Phrase operator

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\" "
           "AND title contains phrase(\"CONSOLIDATED\", \"STATEMENT\") ",
           "offset": 0,
              "hits": 10
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/abda14663cfc2056159a7d28',
#   'relevance': 0.38360530298949064,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
#    'content': 'Consolidated financial statements 164 | Non-financial information 261\n\nA comprehensive view of our financial and non-financial performance, including complete financial statements and sustainability metrics and assurance disclosures.',
#    'url': 'https://s3-qa-8byte.s3.ap-south-1.amazonaws.com/sabic%2Fin%2Fsabic_in_sabic_cc_compressed.pdf',
#    'page_number': 163,
#    'tenant_id': '0f7a4b5f-a137-4a71-b518-1a04ba239b61'}},
#  {'id': 'index:pefund/0/c89cdd4f163e8d0f237beda3',
#   'relevance': 0.38360530298949064,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENT OF FINANCIAL POSITION',
# ...

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND userQuery() ",
           "query": "about financial statements",
    
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/b56c6a9f53a1ff968b2d446e',
#   'relevance': 0.1320088707290152,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
# ...

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND userQuery() ",
           "query": "about summarized statements",
    
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/024fbad81f0252200b863d78',
#   'relevance': 0.06583514603754932,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
# ...

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND userQuery() ",
           "query": "about statements of change in equity",
    
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/253fbd67c81e4f2bfe57f647',
#   'relevance': 0.13117624588542615,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENT OF CHANGES IN EQUITY',
# ...

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND userQuery() ",
           "query": "about shared ownership",
    
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/70a87c2ca8e83a90303f2f72',
#   'relevance': 0.14724023602870123,
#   'source': 'pefund',
#   'fields': {'title': 'SHARE OWNERSHIP',
# ...

# %%
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND userQuery() ",
           "query": "about consolidated statements",
    
}
result = app.query(body=query)
result.hits[:]
# Out:
# [{'id': 'index:pefund/0/abda14663cfc2056159a7d28',
#   'relevance': 0.17654811660629424,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
#    'content': 'Consolidated financial statements 164 | Non-financial information 261\n\nA comprehensive view of our financial and non-financial performance, including complete financial statements and sustainability metrics and assurance disclosures.',
#    'url': 'https://s3-qa-8byte.s3.ap-south-1.amazonaws.com/sabic%2Fin%2Fsabic_in_sabic_cc_compressed.pdf',
#    'page_number': 163,
#    'tenant_id': '0f7a4b5f-a137-4a71-b518-1a04ba239b61'}},
#  {'id': 'index:pefund/0/b56c6a9f53a1ff968b2d446e',
#   'relevance': 0.16539092979790315,
#   'source': 'pefund',
#   'fields': {'title': 'CONSOLIDATED STATEMENTS',
# ...

# %%
import re

def get_page_numbers_with_tables(query_result):
    """
    Extracts page numbers from hits where the content contains a Markdown table.
    """
    hits = query_result.hits[:]
    pages_with_tables = set()  # Use a set to avoid duplicate page numbers

    # Regex looks for lines containing pipes (e.g., "| data | data |")
    # This captures both headers (|---|) and data rows.
    table_pattern = re.compile(r'\|.*\|') 

    for hit in hits:
        fields = hit.get('fields', {})
        content = fields.get('content', '')
        page_num = fields.get('page_number')

        # validation: must have content and a valid page number
        if content and page_num is not None:
            # Check if the content has table markers
            if table_pattern.search(content):
                pages_with_tables.add(page_num)

    # Return as a sorted list
    return sorted(list(pages_with_tables))

# --- Usage ---
# Assuming 'result' is the output from your app.query()
table_pages = get_page_numbers_with_tables(result)

print(f"Pages containing tables: {table_pages}")
# Out:
# Pages containing tables: [238, 239, 240, 273, 274, 275, 279]

# %%
import re

# ==========================================
# 1. Helper Function (Your Logic)
# ==========================================
def get_page_numbers_with_tables(query_result):
    """
    Extracts page numbers from hits where the content contains a Markdown table.
    """
    # Handle both direct list access or .hits depending on client structure
    if hasattr(query_result, 'hits'):
        hits = query_result.hits[:]
    else:
        hits = query_result.get('hits', [])

    pages_with_tables = set()

    # Regex looks for lines containing pipes (e.g., "| data | data |")
    table_pattern = re.compile(r'\|.*\|') 

    for hit in hits:
        fields = hit.get('fields', {})
        content = fields.get('content', '')
        page_num = fields.get('page_number')

        if content and page_num is not None:
            if table_pattern.search(content):
                pages_with_tables.add(page_num)

    return sorted(list(pages_with_tables))

# ==========================================
# 2. Main Logic to Fetch Complete Tables
# ==========================================
def fetch_complete_tables(app, initial_query):
    
    # --- Step 1: Run Initial Query ---
    print("Executing initial user query...")
    initial_result = app.query(body=initial_query)
    
    # Use your function to find pages with tables
    anchor_pages = get_page_numbers_with_tables(initial_result)
    
    if not anchor_pages:
        print("No tables found in initial results.")
        return []

    print(f"Tables detected on pages: {anchor_pages}")

    # --- Step 2: Calculate Surrounding Pages ---
    # We want the current page, previous page, and next page
    pages_to_fetch = set()
    for page in anchor_pages:
        pages_to_fetch.add(max(1, page - 1)) # Previous page (min 1)
        pages_to_fetch.add(page)             # Current page
        pages_to_fetch.add(page + 1)         # Next page
        
    sorted_pages = sorted(list(pages_to_fetch))
    pages_str = ", ".join(map(str, sorted_pages))
    
    # Extract IDs for context query (using the first hit as reference)
    hits = initial_result.hits if hasattr(initial_result, 'hits') else initial_result.get('hits', [])
    first_hit = hits[0]
    tenant_id = first_hit['fields']['tenant_id']
    
    # Extract file_id strictly. 
    # If file_id is in fields use that, otherwise parse from ID or use hardcoded if known.
    # Here we try to parse it dynamically from the result 'id'
    raw_id = first_hit.get('id', '')
    if '/' in raw_id:
        file_id = raw_id.split('/')[-1] # Extracts '79bba865c10d42ac4688de39'
    else:
        # Fallback to the ID used in your original query logic
        file_id = "9de6cf15-b315-4270-92c0-aa648b818949"

    # --- Step 3: Run Context Query ---
    # We remove 'userQuery()' and 'content' filters to get the raw pages
    context_yql = (
        f"select title, page_number, content, url, tenant_id "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND page_number in ({pages_str})"
    )

    context_query_body = {
        "yql": context_yql
    }

    print(f"Fetching full table context (Pages: {pages_str})...")
    final_result = app.query(body=context_query_body)
    
    final_hits = final_result.hits if hasattr(final_result, 'hits') else final_result.get('hits', [])
    
    # Sort by page number so the content is in order
    final_hits.sort(key=lambda x: x['fields'].get('page_number', 0))
    
    return final_hits

# ==========================================
# 3. Execution
# ==========================================

# Your original query
query = {
    "yql": "select title, page_number, content, url, tenant_id "
           "from sources pefund.pefund "
           "where tenant_id contains \"0f7a4b5f-a137-4a71-b518-1a04ba239b61\" "
           "AND file_id contains \"9de6cf15-b315-4270-92c0-aa648b818949\""
           "AND userQuery() ",
    "query": "about consolidated statements",
}

# Run the complete logic
# Ensure 'app' is your database client instance
full_table_hits = fetch_complete_tables(app, query)

print("\n--- Complete Table Data ---")
for hit in full_table_hits:
    p_num = hit['fields']['page_number']
    # Printing a snippet to verify
    print(f"Page {p_num} fetched.")
# Out:
# Executing initial user query...
# Tables detected on pages: [238, 239, 240, 273, 274, 275, 279]
# Fetching full table context (Pages: 237, 238, 239, 240, 241, 272, 273, 274, 275, 276, 278, 279, 280)...
#
# --- Complete Table Data ---

# %%
import re

# ==========================================
# 1. Helper Function: Detect Tables
# ==========================================
def get_page_numbers_with_tables(query_result):
    """
    Extracts page numbers from hits where the content contains a Markdown table.
    """
    # Handle different response structures safely
    if hasattr(query_result, 'hits'):
        hits = query_result.hits
    else:
        hits = query_result.get('hits', [])

    pages_with_tables = set()
    
    # Regex for table rows (lines with pipes)
    table_pattern = re.compile(r'\|.*\|') 

    for hit in hits:
        fields = hit.get('fields', {})
        content = fields.get('content', '')
        page_num = fields.get('page_number')

        if content and page_num is not None:
            if table_pattern.search(content):
                pages_with_tables.add(page_num)

    return sorted(list(pages_with_tables))

# ==========================================
# 2. Main Logic: Fetch Surrounding Pages
# ==========================================
def fetch_complete_tables(app, tenant_id, file_id, user_search_query):
    
    # --- Step 1: Execute Initial Query ---
    # We use the passed variables to construct the query dynamically
    initial_yql = (
        f"select title, page_number, content, url, tenant_id "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND userQuery()"
    )
    
    initial_body = {
        "yql": initial_yql,
        "query": user_search_query
    }
    
    print("Executing initial user query...")
    initial_result = app.query(body=initial_body)
    
    # --- Step 2: Identify Table Pages ---
    anchor_pages = get_page_numbers_with_tables(initial_result)
    
    if not anchor_pages:
        print("No tables found in initial results.")
        return []

    print(f"Tables detected on pages: {anchor_pages}")

    # --- Step 3: Calculate Range (Prev, Curr, Next) ---
    pages_to_fetch = set()
    for page in anchor_pages:
        pages_to_fetch.add(max(1, page - 1)) # Previous page
        pages_to_fetch.add(page)             # Current page
        pages_to_fetch.add(page + 1)         # Next page
        
    sorted_pages = sorted(list(pages_to_fetch))
    # Create string for YQL IN clause: e.g., "272, 273, 274"
    pages_str = ", ".join(map(str, sorted_pages))
    
    # --- Step 4: Execute Context Query ---
    print(f"Fetching full context for pages: {pages_str}...")

    # Note: We removed 'userQuery()' to ensure we get the pages even if keywords are missing
    context_yql = (
        f"select title, page_number, content, url, tenant_id "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND page_number in ({pages_str})"
    )

    context_body = {
        "yql": context_yql
    }

    final_result = app.query(body=context_body)
    
    final_hits = final_result.hits if hasattr(final_result, 'hits') else final_result.get('hits', [])
    
    # Sort results by page number
    final_hits.sort(key=lambda x: x['fields'].get('page_number', 0))
    
    return final_hits

# ==========================================
# 3. Execution Block
# ==========================================

# Define your IDs and Query here
# (I copied these from your provided snippet)
TENANT_ID = "0f7a4b5f-a137-4a71-b518-1a04ba239b61"
FILE_ID   = "9de6cf15-b315-4270-92c0-aa648b818949"
SEARCH_TERM = "about consolidated statements"

# Run the function
# (Make sure 'app' is initialized in your environment)
try:
    final_hits = fetch_complete_tables(app, TENANT_ID, FILE_ID, SEARCH_TERM)
    
    # Print the raw list result as requested
    print("\nFinal Result:")
    print(final_hits)

except NameError:
    print("Error: 'app' is not defined. Please initialize your database client.")
# Out:
# Executing initial user query...
# Tables detected on pages: [238, 239, 240, 273, 274, 275, 279]
# Fetching full context for pages: 237, 238, 239, 240, 241, 272, 273, 274, 275, 276, 278, 279, 280...
#
# Final Result:
# ...

# %%
import re
import json

# ==========================================
# 1. Helper Function: Detect Tables
# ==========================================
def get_page_numbers_with_tables(query_result):
    """
    Extracts page numbers from hits where the content contains a Markdown table.
    """
    if hasattr(query_result, 'hits'):
        hits = query_result.hits
    else:
        hits = query_result.get('hits', [])

    pages_with_tables = set()
    
    # Regex for table rows (lines containing pipes)
    table_pattern = re.compile(r'\|.*\|') 

    for hit in hits:
        fields = hit.get('fields', {})
        content = fields.get('content', '')
        page_num = fields.get('page_number')

        if content and page_num is not None:
            if table_pattern.search(content):
                pages_with_tables.add(page_num)

    return sorted(list(pages_with_tables))

# ==========================================
# 2. Main Logic: Fetch Surrounding Pages
# ==========================================
def fetch_complete_tables(app, tenant_id, file_id, user_search_query):
    
    # --- Step 1: Initial Query ---
    initial_yql = (
        f"select title, page_number, content, url, tenant_id "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND userQuery()"
    )
    
    initial_body = {
        "yql": initial_yql,
        "query": user_search_query
    }
    
    print("Executing initial user query...")
    initial_result = app.query(body=initial_body)
    
    # --- Step 2: Identify Table Pages ---
    anchor_pages = get_page_numbers_with_tables(initial_result)
    
    if not anchor_pages:
        print("No tables found.")
        return []

    print(f"Tables detected on pages: {anchor_pages}")

    # --- Step 3: Calculate Range (Prev, Curr, Next) ---
    pages_to_fetch = set()
    for page in anchor_pages:
        pages_to_fetch.add(max(1, page - 1)) # Previous page
        pages_to_fetch.add(page)             # Current page
        pages_to_fetch.add(page + 1)         # Next page
        
    sorted_pages = sorted(list(pages_to_fetch))
    pages_str = ", ".join(map(str, sorted_pages))
    
    # --- Step 4: Context Query ---
    print(f"Fetching full context for pages: {pages_str}...")

    context_yql = (
        f"select title, page_number, content, url, tenant_id "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND page_number in ({pages_str})"
    )

    context_body = {
        "yql": context_yql
    }

    final_result = app.query(body=context_body)
    
    final_hits = final_result.hits if hasattr(final_result, 'hits') else final_result.get('hits', [])
    
    # Sort by page number
    final_hits.sort(key=lambda x: x['fields'].get('page_number', 0))
    
    return final_hits

# ==========================================
# 3. Execution Block
# ==========================================

TENANT_ID = "0f7a4b5f-a137-4a71-b518-1a04ba239b61"
FILE_ID   = "9de6cf15-b315-4270-92c0-aa648b818949"
SEARCH_TERM = "about consolidated statements of cash flows"

try:
    final_hits = fetch_complete_tables(app, TENANT_ID, FILE_ID, SEARCH_TERM)
    
    print("\nFinal Result (JSON):")
    
    # indent=4 creates the pretty structure
    # default=str handles any special objects (like UUIDs) safely
    print(json.dumps(final_hits, indent=4, default=str))

except NameError:
    print("Error: 'app' is not defined. Please initialize your database client.")
# Out:
# Executing initial user query...
# Tables detected on pages: [63, 175, 176, 178, 238, 239, 240]
# Fetching full context for pages: 62, 63, 64, 174, 175, 176, 177, 178, 179, 237, 238, 239, 240, 241...
#
# Final Result (JSON):
# [
#     {
#         "id": "index:pefund/0/72fbe28c21a7313d48b62910",
#         "relevance": 0.0017429193899782135,
#         "source": "pefund",
#         "fields": {
#             "title": "Geographical distribution of revenues* (%)",
# ...

# %%
import re
import json

# ==========================================
# 1. Helper Function: Detect Tables
# ==========================================
def get_page_numbers_with_tables(query_result):
    """
    Extracts page numbers from hits where the content contains a Markdown table.
    """
    if hasattr(query_result, 'hits'):
        hits = query_result.hits
    else:
        hits = query_result.get('hits', [])

    pages_with_tables = set()
    
    # Regex for table rows (lines containing pipes)
    table_pattern = re.compile(r'\|.*\|') 

    for hit in hits:
        fields = hit.get('fields', {})
        content = fields.get('content', '')
        page_num = fields.get('page_number')

        if content and page_num is not None:
            if table_pattern.search(content):
                pages_with_tables.add(page_num)

    return sorted(list(pages_with_tables))

# ==========================================
# 2. Main Logic: Fetch Surrounding Pages
# ==========================================
def fetch_complete_tables(app, tenant_id, file_id, user_search_query):
    
    # --- Step 1: Initial Query ---
    initial_yql = (
        f"select title, page_number, content, url, tenant_id "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND userQuery()"
    )
    
    initial_body = {
        "yql": initial_yql,
        "query": user_search_query
    }
    
    print("Executing initial user query...")
    initial_result = app.query(body=initial_body)
    
    # --- Step 2: Identify Table Pages ---
    anchor_pages = get_page_numbers_with_tables(initial_result)
    
    if not anchor_pages:
        print("No tables found.")
        return []

    print(f"Tables detected on pages: {anchor_pages}")

    # --- Step 3: Calculate Range (Prev, Curr, Next) ---
    pages_to_fetch = set()
    for page in anchor_pages:
        pages_to_fetch.add(max(1, page - 1)) # Previous page
        pages_to_fetch.add(page)             # Current page
        pages_to_fetch.add(page + 1)         # Next page
        
    sorted_pages = sorted(list(pages_to_fetch))
    pages_str = ", ".join(map(str, sorted_pages))
    
    # --- Step 4: Context Query ---
    print(f"Fetching full context for pages: {pages_str}...")

    context_yql = (
        f"select title, page_number, content, url, tenant_id "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND page_number in ({pages_str})"
    )

    context_body = {
        "yql": context_yql
    }

    final_result = app.query(body=context_body)
    
    final_hits = final_result.hits if hasattr(final_result, 'hits') else final_result.get('hits', [])
    
    # Sort by page number
    final_hits.sort(key=lambda x: x['fields'].get('page_number', 0))
    
    return final_hits

# ==========================================
# 3. Execution & Saving to File
# ==========================================

TENANT_ID = "0f7a4b5f-a137-4a71-b518-1a04ba239b61"
FILE_ID   = "9de6cf15-b315-4270-92c0-aa648b818949"
SEARCH_TERM = "about consolidated statements of income"
OUTPUT_FILENAME = "consolidated_tables.md"

try:
    # 1. Fetch Data
    final_hits = fetch_complete_tables(app, TENANT_ID, FILE_ID, SEARCH_TERM)
    
    if not final_hits:
        print("No content retrieved.")
    else:
        # 2. Write to Markdown File
        print(f"\nSaving content to '{OUTPUT_FILENAME}'...")
        
        with open(OUTPUT_FILENAME, 'w', encoding='utf-8') as f:
            # Add a main title to the document
            f.write(f"# Extracted Tables for: {SEARCH_TERM}\n\n")
            
            for hit in final_hits:
                fields = hit.get('fields', {})
                page_num = fields.get('page_number')
                content = fields.get('content', '')
                
                # Create a clear separator for each page
                f.write(f"\n\n---\n")
                f.write(f"## Page {page_num}\n")
                f.write(f"---\n\n")
                
                # Write the actual markdown content
                f.write(content)
        
        print(f"Successfully saved {len(final_hits)} pages to {OUTPUT_FILENAME}")
        
        # Optional: Still print JSON to console if needed for debugging
        # print(json.dumps(final_hits, indent=4, default=str))

except NameError:
    print("Error: 'app' is not defined. Please initialize your database client.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Executing initial user query...
# Tables detected on pages: [172, 173, 174, 178, 238, 239, 240]
# Fetching full context for pages: 171, 172, 173, 174, 175, 177, 178, 179, 237, 238, 239, 240, 241...
#
# Saving content to 'consolidated_tables.md'...
# Successfully saved 10 pages to consolidated_tables.md

# %% [markdown]
# # Keyword + Semantic search -> dynamic page_number

# %%
TABLE_RECONSTRUCTION_PROMPT = """
You are a Senior Equity Research Analyst and Financial Writer.

INPUT:
1. Vespa page title: {page_title}
2. Text content: {content}

YOUR TASK:
1. Extract ONLY true financial statement tables.
2. Extract the financial statement table and generate a high-precision, professional "description" suitable for inclusion in an Annual Report or an Investment Prospectus.

==================================================
TITLE SELECTION RULES (STRICT)
==================================================
1. First, check the Vespa page title:
   - If it clearly represents a financial statement (e.g., "Consolidated Statement of Cash Flows"), use it EXACTLY as written.
2. If Vespa title is missing or not a financial statement title:
   - Look INSIDE the content for an existing financial statement heading.
3. NEVER invent a title. If no valid title is found, return null.
4. Prefix titles with '### '.

==================================================
TRUE FINANCIAL STATEMENT TABLE DEFINITION
==================================================
A table is a TRUE financial statement table ONLY IF it represents:
- Income statement / Comprehensive Income
- Balance sheet / Financial Position
- Cash flow statement
- Statement of changes in equity

The table MUST contain financial magnitudes (monetary figures) and multiple numeric rows.

==================================================
DESCRIPTION ARCHITECTURE (MANDATORY)
==================================================
The "description" field must be a formal 2-paragraph analysis:

Paragraph 1: Identification & Scope
- Formally identify the statement (e.g., "Consolidated Statement of Operations").
- Specify the reporting entity and the period covered (e.g., "for the fiscal years ended December 31").
- State the currency and scale (e.g., "presented in millions of USD, except per share data").

Paragraph 2: Structural Summary
- Describe the flow of the table. (e.g., "The statement begins with Revenue and flows through operating expenses and tax provisions to arrive at Net Income.")
- Mention key line items or sub-sections included (e.g., "Includes breakdowns for Research & Development, Sales and Marketing, and General Administrative costs.")
- Explain what the table tells a reader about the company's health (e.g., "This provides a view of the company's operational efficiency and bottom-line profitability over the comparative periods.")

==================================================
CRITICAL CONTINUITY & MERGING RULE
==================================================
If a statement is split into sections (e.g., "Operating activities", "Investing activities", "Financing activities"), you MUST MERGE them into ONE continuous table_markdown. DO NOT truncate the table after the first section.

==================================================
RULES FOR THE TABLE (STRICT)
==================================================
1. TITLES: Use the Vespa title if it's a formal name; otherwise, extract the heading from the content. Prefix with '### '.
2. EXCLUSIONS: Do NOT extract narrative text, footnotes, or index tables. Only numeric financial statements.

MANDATORY:
- If table_markdown is present, "description" and "investor_relevance" MUST be populated with high-quality content.

==================================================
OUTPUT FORMAT (JSON ONLY)
==================================================
{{
  "title": "string | null",
  "investor_relevance": "A concise one-sentence statement on why this table is critical for valuation.",
  "description": "The 2-paragraph professional description as defined above.",
  "table_markdown": "The cleaned, reconstructed markdown table."
}}
==================================================
"""

# %%
import re
from concurrent.futures import ThreadPoolExecutor
from langchain_google_genai import ChatGoogleGenerativeAI
from pydantic import BaseModel
from dotenv import load_dotenv
load_dotenv()
import os

# ======================================================
# 0. Models
# ======================================================

class TableResponse(BaseModel):
    title: str | None = None
    investor_relevance: str | None = None
    description: str | None = None
    table_markdown: str | None = None


# ======================================================
# 1. Gemini Setup
# ======================================================

gemini_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=0,
    max_output_tokens=1200,
    api_key=os.getenv("GEMINI_SEARCH_KEY_1")
)

structured_model = gemini_llm.with_structured_output(
    schema=TableResponse.model_json_schema(),
    method="json_schema"
)

# ======================================================
# 2. Regex Helpers
# ======================================================

TABLE_REGEX = re.compile(
    r'(\|.+\|\n\|[-:\s|]+\|\n(?:\|.*\|\n?)*)',
    re.MULTILINE
)

NUMBER_REGEX = re.compile(r'[-+]?\d{1,3}(?:,\d{3})*(?:\.\d+)?')

def has_sufficient_numerical_data(text: str, min_numbers=6) -> bool:
    return len(NUMBER_REGEX.findall(text or "")) >= min_numbers

def is_table_present(content: str) -> bool:
    return any(
        has_sufficient_numerical_data(t)
        for t in TABLE_REGEX.findall(content or "")
    )

# ======================================================
# 3. Vespa Logic (UNCHANGED + PRINTS)
# ======================================================

def get_page_numbers_with_tables(hits):
    pages = {
        h["fields"]["page_number"]
        for h in hits
        if is_table_present(h["fields"].get("content", ""))
    }
    print(f"[INFO] Initial pages with numeric tables: {sorted(pages)}")
    return pages


def fetch_specific_pages(app, tenant_id, file_id, page_list):
    if not page_list:
        return []

    pages_str = ", ".join(map(str, page_list))
    yql = (
        f"select title, page_number, content "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND page_number in ({pages_str})"
    )

    res = app.query(body={"yql": yql, "hits": len(page_list)})
    return res.hits if hasattr(res, "hits") else res.get("hits", [])


def get_complete_table_sequence(app, tenant_id, file_id, query):
    yql = (
        f"select title, page_number, content "
        f"from sources pefund.pefund "
        f"where tenant_id contains \"{tenant_id}\" "
        f"AND file_id contains \"{file_id}\" "
        f"AND (userQuery() or ({{targetHits:100}}nearestNeighbor(question_embeddings,q)))"
    )

    res = app.query({
        "yql": yql,
        "query": query,
        "input.query(q)": f"embed(e5-small-v2, \"{query}\")",
        "ranking": "default",
        "hits": 20
    })

    hits = res.hits if hasattr(res, "hits") else res.get("hits", [])
    confirmed = get_page_numbers_with_tables(hits)
    checked = set()

    while True:
        candidates = {
            n for p in confirmed
            for n in (p - 1, p + 1)
            if n > 0 and n not in confirmed and n not in checked
        }
        if not candidates:
            break

        new_hits = fetch_specific_pages(app, tenant_id, file_id, list(candidates))
        hit_map = {h["fields"]["page_number"]: h for h in new_hits}

        found = False
        for p in candidates:
            hit = hit_map.get(p)
            if not hit:
                checked.add(p)
                continue
            if is_table_present(hit["fields"].get("content", "")):
                confirmed.add(p)
                found = True
            else:
                checked.add(p)

        if not found:
            break

    final_pages = sorted(confirmed)
    print(f"[INFO] Final table pages: {final_pages}")

    final_hits = fetch_specific_pages(app, tenant_id, file_id, final_pages)
    final_hits.sort(key=lambda h: h["fields"]["page_number"])
    return final_hits


# ======================================================
# 4. Parallel Processing (ORDER SAFE)
# ======================================================

def process_single_hit(args):
    idx, hit = args
    result = structured_model.invoke(
        TABLE_RECONSTRUCTION_PROMPT.format(
            page_title=hit["fields"].get("title", ""),
            content=hit["fields"].get("content", "")
        )
    )

    parsed = TableResponse.model_validate(result)

    # 🔒 HARD NUMERIC GATE
    if parsed.table_markdown and not has_sufficient_numerical_data(parsed.table_markdown):
        return idx, TableResponse()

    return idx, parsed

# ======================================================
# 6. Execute
# ======================================================

TENANT_ID = "0f7a4b5f-a137-4a71-b518-1a04ba239b61"
FILE_ID = "9de6cf15-b315-4270-92c0-aa648b818949"
QUERY = "consolidated financial statements"
OUTPUT_FILE = "reconstructed_financial_tables_final_001.md"

hits = get_complete_table_sequence(app, TENANT_ID, FILE_ID, QUERY)

results = [None] * len(hits)

with ThreadPoolExecutor(max_workers=5) as pool:
    for idx, response in pool.map(process_single_hit, enumerate(hits)):
        results[idx] = response

with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    for r in results:
        if r and r.table_markdown:
            # 1. Write the Title
            if r.title:
                f.write(f"{r.title}\n\n")
            
            # 2. Write the Description (The Analysis)
            if r.description:
                f.write(f"### Analysis & Overview\n{r.description}\n\n")
            
            # 3. Write the Investor Relevance
            f.write(f"**Investor Relevance:** {r.investor_relevance}\n\n")
            
            # 4. Write the Table
            f.write(r.table_markdown + "\n\n")
            f.write("---\n\n") # Separator for readability

print(f"[SUCCESS] Extraction completed. Data saved to {OUTPUT_FILE}")
# Out:
# [INFO] Initial pages with numeric tables: [171, 178, 238, 239, 240, 270, 272, 273, 274, 275, 276, 277, 278, 279]
# [INFO] Final table pages: [171, 172, 173, 174, 175, 176, 178, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 269, 270, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281]
# [SUCCESS] Extraction completed. Data saved to reconstructed_financial_tables_final_001.md
